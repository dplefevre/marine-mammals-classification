# %%
import warnings
warnings.filterwarnings('ignore')

import copy
import pandas as pd 

# Requests sends and recieves HTTP requests.
import requests 

# Beautiful soup parses HTML documents in python.
from bs4 import BeautifulSoup

from pymongo import MongoClient
import pprint

# %% [markdown]
# # Step 1: Check out the website in a browser
#
# 1: The table and wav is inside of body /html/body/div[3]/div/div/table/tbody/tr[2]/td[4]/a

# %% [markdown]
# # Step 2: Send a Get request for the data.

# %%
watkins_sounds = "https://cis.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A"

r = requests.get(watkins_sounds)

# %%
r # A status code of 200 means that everything went well
# Out:
# <Response [200]>

# %% [markdown]
# We can check out the raw hypertext in the content attribute of the request.

# %%
r.content
# Out:
# b'\n<!doctype html>\n<html class="no-js" lang="en">\n<head><script type="text/javascript" src="/cf_scripts/scripts/cfform.js"></script>\n<script type="text/javascript" src="/cf_scripts/scripts/masks.js"></script>\n\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n    <title>Watkins Marine Mammal Sound Database</title>\n    <link rel="stylesheet" href="https://www.whoi.edu/cf_headers/watkins/css/foundation.css" />\n    <link rel="stylesheet" href="https://www.whoi.edu/cf_headers/watkins/css/styles.css" />\n    <link rel="stylesheet" href="https://www.whoi.edu/cf_headers/watkins/css/audioplayer.css" />\n    <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/modernizr.js"></script>\n    <script>\n$(\'getSpeciesCommon\').change(function(){\n    var url = $(this).val();\n    window.location = url;\n});\n\t</script>\n\n<script language="JavaScript">\n<!--\nfunction goTo(pagename) {\n    if ((-1 < pagename.selectedIndex) &&\n        (pagename.options[pagename.selectedIndex].value != "nil")) {\n        val = pagename.options[pagename.selectedIndex].value;\n        if(val!="NoValue") {\n            parent.location.href=val;\n            return true;\n        }\n    }\n}\n\nfunction popUpWin(theurl)\n{\n    window.open(theurl,"Metadata",\n"height=375,width=700,location=0,menubar=0,resizable=1,scrollbars=1,status=0,titlebar=1,toolbar=0,hotkeys=0,screenx=0,screeny=0,left=10,top=10");\n}\n\n//-->\n</script>\n<script type="text/javascript">\n<!--\n    _CF_checkjump1 = function(_CF_this)\n    {\n        //reset on submit\n        _CF_error_exists = false;\n        _CF_error_messages = new Array();\n        _CF_error_fields = new Object();\n        _CF_FirstErrorField = null;\n\n\n        //display error messages and return success\n        if( _CF_error_exists )\n        {\n            if( _CF_error_messages.length > 0 )\n            {\n                // show alert() message\n                _CF_onErrorAlert(_CF_error_messages);\n                // set focus to first form error, if the field supports js focus().\n                if( _CF_this[_CF_FirstErrorField].type == "text" )\n                { _CF_this[_CF_FirstErrorField].focus(); }\n\n            }\n            return false;\n        }else {\n            return true;\n        }\n    }\n//-->\n</script>\n<script type="text/javascript">\n<!--\n    _CF_checkjump2 = function(_CF_this)\n    {\n        //reset on submit\n        _CF_error_exists = false;\n        _CF_error_messages = new Array();\n        _CF_error_fields = new Object();\n        _CF_FirstErrorField = null;\n\n\n        //display error messages and return success\n        if( _CF_error_exists )\n        {\n            if( _CF_error_messages.length > 0 )\n            {\n                // show alert() message\n                _CF_onErrorAlert(_CF_error_messages);\n                // set focus to first form error, if the field supports js focus().\n                if( _CF_this[_CF_FirstErrorField].type == "text" )\n                { _CF_this[_CF_FirstErrorField].focus(); }\n\n            }\n            return false;\n        }else {\n            return true;\n        }\n    }\n//-->\n</script>\n</head>\n\n<body>\n\n<div class="brand">\n  <div class="row">\n    <div class="medium-6 columns"> \n\t<a href="https://www.whalingmuseum.org/"><img src="https://www.whoi.edu/cf_headers/watkins/img/NBWM.png" \n\talt=""/></a> </div>\n    \n    <div class="medium-6 columns"> <a href="https://www.whoi.edu"><img \n\tsrc="https://www.whoi.edu/cf_headers/watkins/img/woodsholeoceanographic.png" \n\talt="Woods Hole Oceanographic Institution" style="padding-top:1.15em;float:right;"/></a> </div>\n  </div> \n</div>\n\n    \n\n<div class="banner">   \n  <div class="row">\n    <div class="large-12 columns">\n      <h1><a href="index.cfm"><img src="https://www.whoi.edu/cf_headers/watkins/img/logo.png" alt=""/> \n\tWatkins Marine Mammal Sound Database</a></h1>\n    </div>\n  </div ...

# %%
# connect to the hosted MongoDB instance
client = MongoClient('localhost', 27017)

# %%
# Create a database
db = client['marine_sounds']

# %%
# Create a collection called dolphins

white_sided_dolphins = db['marine_sounds']

# %%
white_sided_dolphins
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'marine_sounds'), 'marine_sounds')

# %% [markdown]
# # Step 3: Save all the hypertext into mongo for later use.

# %%
white_sided_dolphins.insert_one({'html': r.content}) # change name to collections

# %% [markdown]
# # Step 4: Parse the hypertext with BeautifulSoup

# %%
# This is the beautiful part of soup. Parsing the HTML into a python object is effortless.

# %%
soup = BeautifulSoup(r.content, "html")

# %%
print(soup)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <script src="/cf_scripts/scripts/cfform.js" type="text/javascript">
#   </script>
#   <script src="/cf_scripts/scripts/masks.js" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Watkins Marine Mammal Sound Database
#   </title>
#   <link href="https://www.whoi.edu/cf_headers/watkins/css/foundation.css" rel="stylesheet"/>
#   <link href="https://www.whoi.edu/cf_headers/watkins/css/styles.css" rel="stylesheet"/>
#   <link href="https://www.whoi.edu/cf_headers/watkins/css/audioplayer.css" rel="stylesheet"/>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/modernizr.js">
#   </script>
#   <script>
#    $('getSpeciesCommon').change(function(){
#     var url = $(this).val();
#     window.location = url;
# });
#   </script>
#   <script language="JavaScript">
#    <!--
# function goTo(pagename) {
#     if ((-1 < pagename.selectedIndex) &&
#         (pagename.options[pagename.selectedIndex].value != "nil")) {
#         val = pagename.options[pagename.selectedIndex].value;
#         if(val!="NoValue") {
#             parent.location.href=val;
#             return true;
#         }
#     }
# }
#
# function popUpWin(theurl)
# {
#     window.open(theurl,"Metadata",
# "height=375,width=700,location=0,menubar=0,resizable=1,scrollbars=1,status=0,titlebar=1,toolbar=0,hotkeys=0,screenx=0,screeny=0,left=10,top=10");
# }
#
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#     _CF_checkjump1 = function(_CF_this)
#     {
#         //reset on submit
#         _CF_error_exists = false;
#         _CF_error_messages = new Array();
#         _CF_error_fields = new Object();
#         _CF_FirstErrorField = null;
#
#
#         //display error messages and return success
#         if( _CF_error_exists )
#         {
#             if( _CF_error_messages.length > 0 )
#             {
#                 // show alert() message
#                 _CF_onErrorAlert(_CF_error_messages);
#                 // set focus to first form error, if the field supports js focus().
#                 if( _CF_this[_CF_FirstErrorField].type == "text" )
#                 { _CF_this[_CF_FirstErrorField].focus(); }
#
#             }
#             return false;
#         }else {
#             return true;
#         }
#     }
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#     _CF_checkjump2 = function(_CF_this)
#     {
#         //reset on submit
#         _CF_error_exists = false;
#         _CF_error_messages = new Array();
#         _CF_error_fields = new Object();
#         _CF_FirstErrorField = null;
#
#
#         //display error messages and return success
#         if( _CF_error_exists )
#         {
#             if( _CF_error_messages.length > 0 )
#             {
#                 // show alert() message
#                 _CF_onErrorAlert(_CF_error_messages);
#                 // set focus to first form error, if the field supports js focus().
#                 if( _CF_this[_CF_FirstErrorField].type == "text" )
#                 { _CF_this[_CF_FirstErrorField].focus(); }
#
#             }
#             return false;
#         }else {
#             return true;
#         }
#     }
# //-->
#   </script>
#  </head>
#  <body>
#   <div class="brand">
#    <div class="row">
#     <div class="medium-6 columns">
#      <a href="https://www.whalingmuseum.org/">
#       <img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/NBWM.png"/>
#      </a>
#     </div>
#     <div class="medium-6 columns">
#      <a href="https://www.whoi.edu">
#       <img alt="Woods Hole Oceanographic Institution" src="https://www.whoi.edu/cf_headers/watkins/img/woodsholeoceanographic.png" style="padding-top:1.15em;float:right;"/>
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="banner">
#    <div class="row">
#     <div class="large-12 columns">
#      <h1>
#       <a href="index.cfm">
#        <img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/logo.png"/>
#        Watkins Marine Mammal Sound Database
#       </a>
#      </h1>
#     </div>
#    </div>
#   </div>
#   <nav>
#    <div class="row">
#     <div class="large-12 columns">
#      <ul>
#       <li class="active">
#        <a href="index.cfm">
#         ‘Best of’ cuts
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#       <li>
#        <a href="fullCuts.cfm">
#         All cuts
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#       <li>
#        <a href="masterFiles.cfm">
#         Master Tapes
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#       <li>
#        <a href="about.cfm">
#         About
#        </a>
#       </li>
#       <li class="divider hidden-for-small-only">
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <!--Search Database for all the 'best of' species        -->
#   <div class="search-inside">
#    <div class="row">
#     <div class="large-12 columns">
#      <h3>
#       Search the database by name:
#      </h3>
#     </div>
#     <div class="large-6 medium-6 columns">
#      <p>
#       Common name:
#      </p>
#      <form action="/science/B/whalesounds/bestOf.cfm?code=BD6A" id="jump1" method="POST" name="jump1" onsubmit="return _CF_checkjump1(this)">
#       <select id="getSpeciesCommon" name="getSpeciesCommon" onchange="location.href=jump1.getSpeciesCommon.options[selectedIndex].value">
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15F">
#         Atlantic Spotted Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC2A">
#         Bearded Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB1A">
#         Beluga, White Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD19D">
#         Bottlenose Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA1A">
#         Bowhead Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15B">
#         Clymene Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD3B">
#         Common Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE9A">
#         False Killer Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1F">
#         Fin, Finback Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD5A">
#         Fraser's Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD4A">
#         Grampus, Risso's Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC12G">
#         Harp Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC2A">
#         Humpback Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE7A">
#         Killer Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC4A">
#         Leopard Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3C">
#         Long-Finned Pilot Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD10A">
#         Melon Headed Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1A">
#         Minke Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB2A">
#         Narwhal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3A">
#         Northern Right Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15A">
#         Pantropical Spotted Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC14A">
#         Ross Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD17A">
#         Rough-Toothed Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D">
#         Short-Finned (Pacific) Pilot Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3B">
#         Southern Right Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BA2A">
#         Sperm Whale
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15L">
#         Spinner Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15C">
#         Striped Dolphin
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CB1A">
#         Walrus
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC5A">
#         Weddell Seal
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6B">
#         White-beaked Dolphin
#        </option>
#        <option selected="" value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A">
#         White-sided Dolphin
#        </option>
#       </select>
#      </form>
#     </div>
#     <div class="large-6 medium-6 columns">
#      <p>
#       Scientific name:
#      </p>
#      <form action="/science/B/whalesounds/bestOf.cfm?code=BD6A" id="jump2" method="POST" name="jump2" onsubmit="return _CF_checkjump2(this)">
#       <select id="getSpecies" name="getSpecies" onchange="location.href=jump2.getSpecies.options[selectedIndex].value">
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA1A">
#         <i>
#          Balaena mysticetus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1A">
#         <i>
#          Balaenoptera acutorostrata
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC1F">
#         <i>
#          Balaenoptera physalus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB1A">
#         <i>
#          Delphinapterus leucas
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD3B">
#         <i>
#          Delphinus delphis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC2A">
#         <i>
#          Erignathus barbatus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3B">
#         <i>
#          Eubalaena australis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AA3A">
#         <i>
#          Eubalaena glacialis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3C">
#         <i>
#          Globicephala melas
#         </i>
#         (
#         <i>
#          Globicephala melaena, Globicephala edwardii
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE3D">
#         <i>
#          Globicephala macrorhynchus
#         </i>
#         (
#         <i>
#          Globicephala scammoni
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD4A">
#         <i>
#          Grampus griseus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC4A">
#         <i>
#          Hydrurga leptonyx
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD5A">
#         <i>
#          Lagenodelphis hosei
#         </i>
#        </option>
#        <option selected="" value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6A">
#         <i>
#          Lagenorhynchus acutus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD6B">
#         <i>
#          Lagenorhynchus albirostris
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC5A">
#         <i>
#          Leptonychotes weddellii
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=AC2A">
#         <i>
#          Megaptera novaeangliae
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BB2A">
#         <i>
#          Monodon monoceros
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CB1A">
#         <i>
#          Odobenus rosmarus
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC14A">
#         <i>
#          Ommatophoca rossi
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE7A">
#         <i>
#          Orcinus orca
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD10A">
#         <i>
#          Peponocephala electra
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=CC12G">
#         <i>
#          Pagophilus groenlandicus
#         </i>
#         (
#         <i>
#          Phoca groenlandica
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BA2A">
#         <i>
#          Physeter macrocephalus
#         </i>
#         (
#         <i>
#          Physeter catodon
#         </i>
#         )
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BE9A">
#         <i>
#          Pseudorca crassidens
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15A">
#         <i>
#          Stenella attenuata
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15B">
#         <i>
#          Stenella clymene
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15C">
#         <i>
#          Stenella coeruleoalba
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15F">
#         <i>
#          Stenella frontalis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD15L">
#         <i>
#          Stenella longirostris
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD17A">
#         <i>
#          Steno bredanensis
#         </i>
#        </option>
#        <option value="https://whoicf2.whoi.edu/science/B/whalesounds/bestOf.cfm?code=BD19D">
#         <i>
#          Tursiops truncatus
#         </i>
#         (
#         <i>
#          Tursiops gilli
#         </i>
#         )
#        </option>
#       </select>
#      </form>
#     </div>
#    </div>
#   </div>
#   <div class="database">
#    <div class="row">
#     <div class="large-12 columns">
#      <h3>
#       Best of White-sided Dolphin
# (
#       <i>
#        Lagenorhynchus acutus
#       </i>
#       )
# 	      	55 sound cut
# 		files
#      </h3>
#      <p>
#       See the 'About' section for
#       <a href="about.cfm#credit" target="_blank">
#        crediting
#       </a>
#       and
#       <a href="about.cfm#download" target="_blank">
#        download instructions
#       </a>
#       .
#      </p>
#      <table>
#       <tr>
#        <th>
#         Sound cut file
#        </th>
#        <th>
#         Location
#        </th>
#        <th>
#         Observation Date
#        </th>
#        <th>
#         <strong>
#          Download link
#         </strong>
#        </th>
#        <th>
#         <strong>
#          Metadata
#         </strong>
#        </th>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072004.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072004.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072004');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072005.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072005.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072005');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072006.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072006.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072006');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200E.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200E.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200E');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200G.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200G.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200G');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200H.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200H.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200H');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200K.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200K.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200K');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200M.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200M.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200M');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200O.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200O.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200O');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200R.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200R.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200R');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200S.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200S.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200S');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200T.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200T.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200T');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107200Z.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107200Z.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107200Z');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072013.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072013.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072013');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107201H.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107201H.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107201H');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107201N.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107201N.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107201N');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107201P.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107201P.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107201P');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107201X.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107201X.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107201X');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072020.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072020.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072020');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072021.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072021.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072021');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072022.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072022.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072022');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072023.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072023.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072023');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202D.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202D.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202D');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202K.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202K.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202K');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202L.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202L.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202L');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202N.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202N.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202N');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202O.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202O.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202O');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202R.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202R.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202R');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/6107202T.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/6107202T.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=6107202T');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072031.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072031.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072031');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/61072032.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#        </td>
#        <td>
#         30-Sep-1961
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/61072032.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=61072032');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500100Y.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500100Y.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500100Y');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/75001019.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/75001019.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=75001019');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500101N.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500101N.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500101N');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500101P.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500101P.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500101P');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/75001021.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank    X
#        </td>
#        <td>
#         5-Sep-1975    X
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/75001021.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=75001021');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500102G.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500102G.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500102G');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500102H.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500102H.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500102H');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500102I.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500102I.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500102I');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500102R.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500102R.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500102R');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500102S.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500102S.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500102S');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500103D.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500103D.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500103D');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7500103V.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         SE of Browns Bank
#        </td>
#        <td>
#         5-Sep-1975
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7500103V.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7500103V');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/78007015.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         14 mi. NNW Race Point, Provincetown, MA
#        </td>
#        <td>
#         3-May-1978
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/78007015.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=78007015');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7800701J.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         14 mi. NNW Race Point, Provincetown, MA
#        </td>
#        <td>
#         3-May-1978
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7800701J.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7800701J');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/78007038.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         14 mi. NNW Race Point, Provincetown, MA
#        </td>
#        <td>
#         3-May-1978
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/78007038.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=78007038');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/7800703Q.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         14 mi. NNW Race Point, Provincetown, MA
#        </td>
#        <td>
#         3-May-1978
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/7800703Q.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=7800703Q');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79004007.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         Stellwagen Bank, 13 mi. N-NE Race Point, Provincetown, MA
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79004007.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79004007');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79004016.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         Stellwagen Bank, 13 mi. N-NE Race Point, Provincetown, MA
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79004016.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79004016');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79006014.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         E of Stellwagen Bank
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79006014.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79006014');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79006015.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         E of Stellwagen Bank
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79006015.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79006015');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79006016.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         E of Stellwagen Bank
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79006016.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79006016');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79006017.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         E of Stellwagen Bank
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79006017.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79006017');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79006018.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         E of Stellwagen Bank
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79006018.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79006018');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td>
#         <audio controls="">
#          <source src="/science/B/whalesounds/WhaleSounds/79006019.wav" type="audio/wav">
#          </source>
#         </audio>
#        </td>
#        <td>
#         E of Stellwagen Bank
#        </td>
#        <td>
#         25-Apr-1979
#        </td>
#        <td>
#         <a href="/science/B/whalesounds/WhaleSounds/79006019.wav" target="_blank">
#          Download
#         </a>
#        </td>
#        <td>
#         <a href="javascript:popUpWin('metaData.cfm?RN=79006019');">
#          Metadata
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </div>
#   </div>
#   <!-- footer -->
#   <footer>
#    <div class="row">
#     <div class="large-9 columns">
#      <p>
#       This database was proudly funded by:
#      </p>
#      <div class="row">
#       <div class="large-6 columns">
#        <a href="https://www.whoi.edu/website/mmc/home/">
#         <img alt="" src="https://www.whoi.edu/cf_headers/watkins/img/logo-mmc.png"/>
#        </a>
#       </div>
#       <div class="large-6 columns">
#        <p>
#         The Marine Mammal Center conducts basic research, using cutting-edge
# 	technology to solve major scientific and conservation challenges. Its scientists and engineers
# 	integrate diverse approaches and methods to understanding marine mammals and the different ways
# 	humans may influence their health, populations, and ecosystems.
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="large-3 columns">
#      <p>
#      </p>
#      <p>
#       ©
#       <script type="text/javascript">
#        var year = new Date();document.write(year.getFullYear());
#       </script>
#       Watkins Marine Mammal Sound Database. All rights reserved.
#       For trouble with this site, contact:
#       <a href="mailto:webapp-support@whoi.edu">
#        webapp-support@whoi.edu
#       </a>
#      </p>
#     </div>
#    </div>
#   </footer>
#   <script>
#    $(document).foundation();
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/vendor/jquery.js">
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/foundation.min.js">
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/jquery.js">
#   </script>
#   <script src="https://www.whoi.edu/cf_headers/watkins/js/audioplayer.js">
#   </script>
#   <script>
#    $(document).foundation();
#   </script>
#   <script>
#    $( function() {$('audio').audioPlayer();});
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-77353200-1', 'auto');
#   ga('send', 'pageview');
#   </script>
#  </body>
# </html>

# %%
print(soup.title)

# %% [markdown]
# # Step 5: Navigate the data to pull out the table information
#
# Recall the structure of the table we are looking for:

# %%
div = soup.find("div", {"class": "database"})

table = div.find("table")

# %%
# This returns an iterator over the rows in the table
rows = table.find_all("tr")

# %%
import re 

links = [a['href'] for a in soup.find_all('a',href=re.compile('/science.*\.(mp3|wav|ogg|wma)'))]

# %%
from pydub import AudioSegment
from pydub.playback import play

# %%
def download_audio_and_save(lst_of_urls):
    
    for idx, url in enumerate(lst_of_urls):
        doc = requests.get(f'https://whoicf2.whoi.edu{url}')

        with open(f'training_data/Watkins/white sided dolphin/whiteDolphin{idx}.wav', 'wb') as f:
            f.write(doc.content)
            print(f"Saved audio file{idx}")

# %%
download_audio_and_save(links)
# Out:
# Saved audio file0
# Saved audio file1
# Saved audio file2
# Saved audio file3
# Saved audio file4
# Saved audio file5
# Saved audio file6
# Saved audio file7
# Saved audio file8
# Saved audio file9
# Saved audio file10
# Saved audio file11
# Saved audio file12
# Saved audio file13
# Saved audio file14
# Saved audio file15
# Saved audio file16
# Saved audio file17
# Saved audio file18
# Saved audio file19
# Saved audio file20
# Saved audio file21
# Saved audio file22
# Saved audio file23
# Saved audio file24
# Saved audio file25
# Saved audio file26
# Saved audio file27
# Saved audio file28
# Saved audio file29
# Saved audio file30
# Saved audio file31
# Saved audio file32
# Saved audio file33
# Saved audio file34
# Saved audio file35
# Saved audio file36
# Saved audio file37
# Saved audio file38
# Saved audio file39
# Saved audio file40
# Saved audio file41
# Saved audio file42
# Saved audio file43
# Saved audio file44
# Saved audio file45
# Saved audio file46
# Saved audio file47
# Saved audio file48
# Saved audio file49
# Saved audio file50
# Saved audio file51
# Saved audio file52
# Saved audio file53
# Saved audio file54
